# %%
print("Intro to pandas")
# Out:
# Intro to pandas

# %%
import pandas as pd

# Series = 1 dimensional datatype in pandas
s = pd.Series((1,2,3,4,5))
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# changing the index values to a,b,c,d and e 
new_s = pd.Series((1,2,3,4,5), index = ['a','b','c','d','e'])

# %%
new_s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# DataFrame = 2 dimensional datatype in pandas
df1 = pd.DataFrame({"names": ['Sneha','Amisha'], "marks": [97,98]})
df1
# Out:
#     names  marks
# 0   Sneha     97
# 1  Amisha     98

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\pandas\diamond.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# Data Selection

# %%
# selecting a particular column
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
type(df['carat'])    #series = 1-D
# Out:
# pandas.core.series.Series

# %%
df[["carat","clarity"]]
# Out:
#        carat clarity
# 0       0.23     SI2
# 1       0.21     SI1
# 2       0.23     VS1
# 3       0.29     VS2
# 4       0.31     SI2
# ...      ...     ...
# 53935   0.72     SI1
# 53936   0.72     SI1
# 53937   0.70     SI1
# 53938   0.86     SI2
# 53939   0.75     SI2
#
# [53940 rows x 2 columns]

# %%
type(df[["carat","clarity"]])     # DataFrame = 2-D
# Out:
# pandas.core.frame.DataFrame

# %%
# this will print the row at index 0 of each column
df.iloc[0]
# Out:
# Unnamed: 0        1
# carat          0.23
# cut           Ideal
# color             E
# clarity         SI2
# depth          61.5
# table          55.0
# price           326
# x              3.95
# y              3.98
# z              2.43
# Name: 0, dtype: object

# %%
type(df.iloc[0])   # Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# Dealing with Null values

# %%
# Reading a csv file (having null value at index 1(row 2))
df2 = pd.read_csv(r"C:\Users\HP\Desktop\pandas\NullFileEg.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1    NaN   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df2.dropna()   # fn to remove the rows having null values
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# filling the null values with 0
df2.fillna(0)     # if attribut, inplace = True => It will replace the original file
# Out:
#      name  marks
# 0   Sneha     98
# 1  Shruti     97
# 2   Kajal     95
# 3  Kumkum     94

# %%
# to rename any column
df.rename(columns= {"price":"cost"})
# this will not replace the actual dataframe, instead create a new df if attribute "inplace = True" is not mentioned
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  cost     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0   326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0   326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0   327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0   334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0   335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0  2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0  2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0  2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0  2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0  2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# to rename any column in actual df as well
df.rename(columns= {"price":"cost"}, inplace = True)
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  cost     x  \
# 0               1      0      Ideal     E     SI2   61.5   55.0   326  3.95
# 1               2      0    Premium     E     SI1   59.8   61.0   326  3.89
# 2               3      0       Good     E     VS1   56.9   65.0   327  4.05
# 3               4      0    Premium     I     VS2   62.4   58.0   334  4.20
# 4               5      0       Good     J     SI2   63.3   58.0   335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53935       53936      0      Ideal     D     SI1   60.8   57.0  2757  5.75
# 53936       53937      0       Good     D     SI1   63.1   55.0  2757  5.69
# 53937       53938      0  Very Good     D     SI1   62.8   60.0  2757  5.66
# 53938       53939      0    Premium     H     SI2   61.0   58.0  2757  6.15
# 53939       53940      0      Ideal     D     SI2   62.2   55.0  2757  5.83
#
#           y     z  Zeroes        ones
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   cost        53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
# changing the datatype of 'carat' from 'float' to 'int'
df['carat'] = df['carat'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  int32
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   cost        53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(5), int32(1), int64(2), object(3)
# memory usage: 4.3+ MB

# %%
df   # values of carat are now integers
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  cost     x  \
# 0               1      0      Ideal     E     SI2   61.5   55.0   326  3.95
# 1               2      0    Premium     E     SI1   59.8   61.0   326  3.89
# 2               3      0       Good     E     VS1   56.9   65.0   327  4.05
# 3               4      0    Premium     I     VS2   62.4   58.0   334  4.20
# 4               5      0       Good     J     SI2   63.3   58.0   335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53935       53936      0      Ideal     D     SI1   60.8   57.0  2757  5.75
# 53936       53937      0       Good     D     SI1   63.1   55.0  2757  5.69
# 53937       53938      0  Very Good     D     SI1   62.8   60.0  2757  5.66
# 53938       53939      0    Premium     H     SI2   61.0   58.0  2757  6.15
# 53939       53940      0      Ideal     D     SI2   62.2   55.0  2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
len(df)  # returns no. of rows in df
# Out:
# 53940

# %%
# to add a new column 'Zeroes'
df['Zeroes'] = [i for i in range(len(df))]   # on rhs, we've provided list of vlaues of new column
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  cost     x  \
# 0               1      0      Ideal     E     SI2   61.5   55.0   326  3.95
# 1               2      0    Premium     E     SI1   59.8   61.0   326  3.89
# 2               3      0       Good     E     VS1   56.9   65.0   327  4.05
# 3               4      0    Premium     I     VS2   62.4   58.0   334  4.20
# 4               5      0       Good     J     SI2   63.3   58.0   335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53935       53936      0      Ideal     D     SI1   60.8   57.0  2757  5.75
# 53936       53937      0       Good     D     SI1   63.1   55.0  2757  5.69
# 53937       53938      0  Very Good     D     SI1   62.8   60.0  2757  5.66
# 53938       53939      0    Premium     H     SI2   61.0   58.0  2757  6.15
# 53939       53940      0      Ideal     D     SI2   62.2   55.0  2757  5.83
#
#           y     z  Zeroes
# 0      3.98  2.43       0
# ...

# %%
# creating a new column using any particular column(by applying function on it using 'apply')
def fx(a):
    return a *a

df['ones'] = df['Zeroes'] .apply(fx)

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  cost     x  \
# 0               1      0      Ideal     E     SI2   61.5   55.0   326  3.95
# 1               2      0    Premium     E     SI1   59.8   61.0   326  3.89
# 2               3      0       Good     E     VS1   56.9   65.0   327  4.05
# 3               4      0    Premium     I     VS2   62.4   58.0   334  4.20
# 4               5      0       Good     J     SI2   63.3   58.0   335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53935       53936      0      Ideal     D     SI1   60.8   57.0  2757  5.75
# 53936       53937      0       Good     D     SI1   63.1   55.0  2757  5.69
# 53937       53938      0  Very Good     D     SI1   62.8   60.0  2757  5.66
# 53938       53939      0    Premium     H     SI2   61.0   58.0  2757  6.15
# 53939       53940      0      Ideal     D     SI2   62.2   55.0  2757  5.83
#
#           y     z  Zeroes        ones
# ...

# %%
# to save the file in required format
df.to_csv("export.csv")
# this will return the index values(when opened in excel) with the data in output file

# %%
# to save without index file
df.to_csv("export1.csv", index= False)

# %%
df3 = pd.DataFrame({
    "name" : ["Sneha","Shruti", "Kajal", "Kumkum"],
    "marks" : [98, 97, 95, 94]
})

# %%
df3
# Out:
#      name  marks
# 0   Sneha     98
# 1  Shruti     97
# 2   Kajal     95
# 3  Kumkum     94

# %%
df4 = pd.DataFrame({
    "name" : ["Amisha","Priyanka", "Karishma", "Kritika"],
    "marks" : [89, 91, 92, 93]
})
df4
# Out:
#        name  marks
# 0    Amisha     89
# 1  Priyanka     91
# 2  Karishma     92
# 3   Kritika     93

# %%
# merging dataframes
pd.concat([df3,df4])
# Out:
#        name  marks
# 0     Sneha     98
# 1    Shruti     97
# 2     Kajal     95
# 3    Kumkum     94
# 0    Amisha     89
# 1  Priyanka     91
# 2  Karishma     92
# 3   Kritika     93

# %%
df5 = pd.DataFrame({
    "name" : ["Amisha","Priyanka", "Karishma", "Kritika"],
    "roll no" : [1, 2, 3, 4]
})
df5
# Out:
#        name  roll no
# 0    Amisha        1
# 1  Priyanka        2
# 2  Karishma        3
# 3   Kritika        4

# %%
pd.concat([df4,df5])   # this will give many null values
# Out:
#        name  marks  roll no
# 0    Amisha   89.0      NaN
# 1  Priyanka   91.0      NaN
# 2  Karishma   92.0      NaN
# 3   Kritika   93.0      NaN
# 0    Amisha    NaN      1.0
# 1  Priyanka    NaN      2.0
# 2  Karishma    NaN      3.0
# 3   Kritika    NaN      4.0

# %%
pd.merge(df4,df5, on="name")
# Out:
#        name  marks  roll no
# 0    Amisha     89        1
# 1  Priyanka     91        2
# 2  Karishma     92        3
# 3   Kritika     93        4
